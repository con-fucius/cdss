# %% [markdown]
# # UMLS CDSS - Data Exploration
#
# This notebook explores the UMLS dataset and clinical data used for the CDSS system.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load UMLS concepts
# TODO: Load from database or CSV

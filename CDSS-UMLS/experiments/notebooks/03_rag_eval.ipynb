# %% [markdown]
# # RAG Evaluation
#
# Compare different RAG implementations (v1, v2, v3) on clinical queries.

# %%
import pandas as pd
from api.services.evaluation.metrics import MetricsCalculator

# TODO: Run RAG evaluations
